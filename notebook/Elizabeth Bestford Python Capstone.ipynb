# %%
import pandas as pd

# %%
national_NH=pd.read_csv('../data/NH_capstone_data_CSV.csv')
national_NH.head()
# Out:
#   Processing Date                                Provider Name     City/Town  \
# 0        1/1/2025                     BURNS NURSING HOME, INC.  RUSSELLVILLE
# 1        1/1/2025               COOSA VALLEY HEALTHCARE CENTER     SYLACAUGA
# 2        1/1/2025                   HIGHLANDS HEALTH AND REHAB    SCOTTSBORO
# 3        1/1/2025  EASTVIEW REHABILITATION & HEALTHCARE CENTER    BIRMINGHAM
# 4        1/1/2025                PLANTATION MANOR NURSING HOME      MC CALLA
#
#   State County/Parish           Ownership Type  Number of Certified Beds  \
# 0    AL      Franklin               For Profit                        57
# 1    AL     Talladega               For Profit                        85
# 2    AL       Jackson  Government- City/County                        50
# 3    AL     Jefferson               For Profit                        92
# 4    AL     Jefferson               For Profit                       103
#
# ...

# %%
national_NH[['State']].value_counts()
# Out:
# State
# TX       1174
# CA       1150
# OH        914
# FL        679
# IL        670
# PA        657
# NY        587
# MO        480
# IN        472
# MI        418
# NC        411
# IA        385
# NJ        344
# MA        336
# MN        323
# WI        315
# GA        300
# TN        299
# KS        297
# VA        285
# OK        282
# KY        263
# LA        262
# AL        221
# AR        217
# MD        215
# CO        208
# MS        196
# CT        193
# WA        190
# SC        179
# NE        168
# AZ        139
# OR        125
# WV        122
# UT         94
# SD         88
# ID         78
# ME         73
# NH         72
# ND         72
# RI         72
# NV         67
# NM         66
# MT         55
# DE         43
# HI         40
# WY         35
# VT         33
# DC         16
# AK         16
# PR          6
# GU          1
# Name: count, dtype: int64

# %%
national_NH[['State','Ownership Type']].value_counts()
# Out:
# State  Ownership Type
# CA     For Profit                 1008
# TX     For Profit                  847
# OH     For Profit                  770
# IL     For Profit                  547
# FL     For Profit                  537
#                                   ...
# ND     Government- City/County       1
# NE     Government - Federal          1
# UT     Government - State            1
# NV     Government - State            1
# IA     Government - State            1
# Name: count, Length: 256, dtype: int64
